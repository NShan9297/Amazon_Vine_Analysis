# %%
import pandas as pd

# %%
import numpy as np

# %%
vine_data_to_load="Resources/vine_analysis.csv"

# %%
vine_data_df=pd.read_csv(vine_data_to_load)

# %%
vine_data_df.head()
# Out:
#         review_id  star_rating  helpful_votes  total_votes vine  \
# 0   RY01SAV7HZ8QO            4              0            0    N
# 1  R1XX8SDGJ4MZ4L            5              0            0    N
# 2  R149Q3B5L33NN5            5              0            0    N
# 3  R2ZVD69Z6KPJ4O            1              0            2    N
# 4  R1DIKG2G33ZLNP            4              0            0    N
#
#   verified_purchase
# 0                 Y
# 1                 N
# 2                 Y
# 3                 Y
# 4                 Y

# %%
vine_twenty_df=vine_data_df.loc[(vine_data_df["total_votes"]>= 20)]

# %%
vine_twenty_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 36      R1VCSDR38XTALJ            1             33           40    N
# 189     R1KMC6B2JRCZ3D            3             42           47    N
# 190     R1LV778IDGRJQ6            1              4           23    N
# 222      RBZE8H6SHVYWW            3             77          110    N
# 368     R2LBEAGVJA7HK1            3              5           48    N
# ...                ...          ...            ...          ...  ...
# 705839  R30RTJOFY20EXZ            2             51           59    N
# 705842  R3M646A6GS49CA            5             27           29    N
# 705859   R43PXU4ZN2AL1            1             10           20    N
# 705878   RJ3B6LDE2HP5J            5             29           30    N
# 705887  R1QCR0Q06G5NZF            3              2           21    N
#
#        verified_purchase
# 36                     N
# 189                    N
# 190                    Y
# 222                    N
# ...

# %%
vine_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705889 entries, 0 to 705888
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   review_id          705889 non-null  object
#  1   star_rating        705889 non-null  int64
#  2   helpful_votes      705889 non-null  int64
#  3   total_votes        705889 non-null  int64
#  4   vine               705889 non-null  object
#  5   verified_purchase  705889 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 32.3+ MB

# %%
new_df=vine_twenty_df.loc[(vine_twenty_df["helpful_votes"]/vine_twenty_df["total_votes"]>= .5)]

# %%
new_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 36      R1VCSDR38XTALJ            1             33           40    N
# 189     R1KMC6B2JRCZ3D            3             42           47    N
# 222      RBZE8H6SHVYWW            3             77          110    N
# 420     R3UN4H3BW9YTQA            5            358          388    N
# 429      R2YKRQ8R3B2Q3            5             30           35    N
# ...                ...          ...            ...          ...  ...
# 705834  R36M104UOY2KXC            5             20           26    N
# 705839  R30RTJOFY20EXZ            2             51           59    N
# 705842  R3M646A6GS49CA            5             27           29    N
# 705859   R43PXU4ZN2AL1            1             10           20    N
# 705878   RJ3B6LDE2HP5J            5             29           30    N
#
#        verified_purchase
# 36                     N
# 189                    N
# 222                    N
# 420                    Y
# ...

# %%
new_vine_df=new_df.loc[(new_df["vine"]=='Y')]

# %%
new_vine_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 2359    R3LLICBKRHLRJC            4             17           22    Y
# 4451     RUD135S06DEVE            5             41           51    Y
# 5075    R2WG8UL4SGDPDH            4             23           25    Y
# 5083    R158AOKOA28WS2            4             18           28    Y
# 5223     RGWV3QLJQXU9X            5            332          380    Y
# ...                ...          ...            ...          ...  ...
# 618371  R2IQBIWSNKQ0RS            4             25           25    Y
# 634479   REGI2TZSHK1RQ            4             39           45    Y
# 634628  R38TDIRKVLCJDS            5             14           20    Y
# 637784  R1XDXXIF59L1IL            3             66           75    Y
# 637789   RQLC3CUPHJ86V            5            123          129    Y
#
#        verified_purchase
# 2359                   N
# 4451                   N
# 5075                   N
# 5083                   N
# ...

# %%
y_star_rate=new_vine_df.loc[(new_vine_df["star_rating"]==5)]
y_star_rate
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 4451     RUD135S06DEVE            5             41           51    Y
# 5223     RGWV3QLJQXU9X            5            332          380    Y
# 8079     RD0E1RZSSYGGN            5            261          292    Y
# 15810   R3LGCTQH5ZMGO0            5             61           68    Y
# 19274    RYYTC9JTG7WPW            5            107          134    Y
# ...                ...          ...            ...          ...  ...
# 576232  R1J4XTCD9XS3PH            5             78           86    Y
# 576338  R1WWUTI62EPAFO            5             40           43    Y
# 581265  R37GDBIPTER2CU            5            203          210    Y
# 634628  R38TDIRKVLCJDS            5             14           20    Y
# 637789   RQLC3CUPHJ86V            5            123          129    Y
#
#        verified_purchase
# 4451                   N
# 5223                   N
# 8079                   N
# 15810                  N
# ...

# %%
y_rating_df=y_star_rate["star_rating"].count()/new_vine_df["star_rating"].count()*100
y_rating_df
# Out:
# 40.61302681992337

# %%
n_new_vine_df=new_df.loc[(new_df["vine"]=='N')]

# %%
n_new_vine_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 36      R1VCSDR38XTALJ            1             33           40    N
# 189     R1KMC6B2JRCZ3D            3             42           47    N
# 222      RBZE8H6SHVYWW            3             77          110    N
# 420     R3UN4H3BW9YTQA            5            358          388    N
# 429      R2YKRQ8R3B2Q3            5             30           35    N
# ...                ...          ...            ...          ...  ...
# 705834  R36M104UOY2KXC            5             20           26    N
# 705839  R30RTJOFY20EXZ            2             51           59    N
# 705842  R3M646A6GS49CA            5             27           29    N
# 705859   R43PXU4ZN2AL1            1             10           20    N
# 705878   RJ3B6LDE2HP5J            5             29           30    N
#
#        verified_purchase
# 36                     N
# 189                    N
# 222                    N
# 420                    Y
# ...

# %%
n_star_rate=n_new_vine_df.loc[(n_new_vine_df["star_rating"]==5)]
n_star_rate
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 420     R3UN4H3BW9YTQA            5            358          388    N
# 429      R2YKRQ8R3B2Q3            5             30           35    N
# 679      RJQQO26UPW1PI            5             76           96    N
# 776     R14QWM0LJO6313            5             24           28    N
# 841     R19H4AKN005KL8            5             19           28    N
# ...                ...          ...            ...          ...  ...
# 705820  R3GUDLJV9Y2QXR            5             58           60    N
# 705826  R2TVIS5UTPU53F            5             26           27    N
# 705834  R36M104UOY2KXC            5             20           26    N
# 705842  R3M646A6GS49CA            5             27           29    N
# 705878   RJ3B6LDE2HP5J            5             29           30    N
#
#        verified_purchase
# 420                    Y
# 429                    N
# 679                    Y
# 776                    Y
# ...

# %%
n_rating_df=n_star_rate["star_rating"].count()/n_new_vine_df["star_rating"].count()*100
n_rating_df
# Out:
# 45.3369384359401
